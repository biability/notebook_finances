# %%
import nasdaqdatalink
from tabulate import tabulate
nasdaqdatalink.ApiConfig.verify_ssl = False
nasdaqdatalink.ApiConfig.api_key = "vKxz-D6X8CbkYzNPmDp3"

# %%
data = nasdaqdatalink.get_table('ZACKS/FC')
# Out:
# /Users/carlos/Projects/finanzas/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'data.nasdaq.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
#print(tabulate(data, tablefmt="grid"))
data
# Out:
#      m_ticker ticker                        comp_name  \
# None
# 0         WMS    WMT                          Walmart
# 1         WMS    WMT                          Walmart
# 2         WMS    WMT                          Walmart
# 3         WMS    WMT                          Walmart
# 4         WMS    WMT                          Walmart
# 5        VISA      V                             Visa
# 6        VISA      V                             Visa
# 7        VISA      V                             Visa
# 8        VISA      V                             Visa
# 9        VISA      V                             Visa
# 10       UNIH    UNH               UnitedHealth Group
# 11       UNIH    UNH               UnitedHealth Group
# 12       UNIH    UNH               UnitedHealth Group
# 13       UNIH    UNH               UnitedHealth Group
# 14       UNIH    UNH               UnitedHealth Group
# 15        SPM    TRV          The Travelers Companies
# ...
